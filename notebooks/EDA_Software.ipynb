# %% [markdown]
# # EDA Software

# %% [markdown]
# ## Librerias

# %%
import warnings
import pandas as pd
import numpy  as np
import seaborn as sns
import matplotlib.pyplot as plt
# Suppress all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Clases

# %%
from src.utils import path

# %% [markdown]
# ## Carga de DataSet

# %%
directorio_proyecto = path.obtener_ruta_local()
df = pd.read_csv(directorio_proyecto+'\\data\\raw\\Software.csv',delimiter = ',',decimal = ".", encoding='utf-8')

# %%
# primeras filas
print("PRIMERAS FILAS DEL DATASET")
display(df.head(5))

print("ÚLTIMAS FILAS DEL DATASET")
display(df.tail(5))
# Out:
# PRIMERAS FILAS DEL DATASET
#    Row ID          Order ID  Order Date  Date Key    Contact Name  \
# 0       1  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 1       2  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 2       3  AMER-2022-138688   6/13/2022  20220613  Deirdre Bailey
# 3       4  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
# 4       5  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License  \
# 0         1017   Energy        SMB         Marketing Suite  16GRM07R1K
# 1         1017   Energy        SMB              FinanceHub  QLIW57KZUV
# 2         1056   Energy  Strategic              FinanceHub  JI6BVL70HQ
# 3         1031   Energy        SMB          ContactMatcher  DE9GJKGD44
# 4         1031   Energy        SMB  Marketing Suite - Gold  OIF7NY23WD
#
#       Sales  Quantity  Discount    Profit
# 0  261.9600         2      0.00   41.9136
# 1  731.9400         3      0.00  219.5820
# 2   14.6200         2      0.00    6.8714
# 3  957.5775         5      0.45 -383.0310
# 4   22.3680         2      0.20    2.5164
# ÚLTIMAS FILAS DEL DATASET
#       Row ID          Order ID Order Date  Date Key       Contact Name  \
# 9989    9990  EMEA-2020-110422  1/22/2020  20200122          Dan Allan
# 9990    9991  AMER-2023-121258  2/27/2023  20230227  Anthony Sanderson
# 9991    9992  AMER-2023-121258  2/27/2023  20230227  Anthony Sanderson
# 9992    9993  AMER-2023-121258  2/27/2023  20230227  Anthony Sanderson
# 9993    9994  AMER-2023-119914   5/5/2023  20230505   Jasmine Springer
#
#             Country       City Region Subregion           Customer  \
# 9989        Germany    Hamburg   EMEA   EU-WEST  Johnson & Johnson
# 9990  United States  Milwaukee   AMER     NAMER   American Express
# 9991  United States  Milwaukee   AMER     NAMER   American Express
# 9992  United States  Milwaukee   AMER     NAMER   American Express
# 9993  United States     Dallas   AMER     NAMER            Comcast
#
#       Customer ID        Industry Segment              Product     License  \
# 9989         1055      Healthcare     SMB  SaaS Connector Pack  ETHXMB5TMD
# 9990         1005         Finance     SMB  SaaS Connector Pack  LYHOKTRY7L
# 9991         1005         Finance     SMB       Site Analytics  I5SVMI6M88
# 9992         1005         Finance     SMB              Support  JHLW4P6LQ2
# 9993         1022  Communications     SMB              OneView  3NTBV9B3PS
#
#         Sales  Quantity  Discount   Profit
# 9989   25.248         3       0.2   4.1028
# 9990   91.960         2       0.0  15.6332
# 9991  258.576         2       0.2  19.3932
# 9992   29.600         4       0.0  13.3200
# 9993  243.160         2       0.0  72.9480

# %%
# Dimensiones del dataset
print("DIMENSIONES DEL DATASET")
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")

# Información general
print("INFORMACIÓN GENERAL")
df.info()
# Out:
# DIMENSIONES DEL DATASET
# Número de filas: 9994
# Número de columnas: 19
# INFORMACIÓN GENERAL
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   object
#  2   Order Date    9994 non-null   object
#  3   Date Key      9994 non-null   int64
#  4   Contact Name  9994 non-null   object
#  5   Country       9994 non-null   object
#  6   City          9994 non-null   object
#  7   Region        9994 non-null   object
#  8   Subregion     9994 non-null   object
#  9   Customer      9994 non-null   object
#  10  Customer ID   9994 non-null   int64
#  11  Industry      9994 non-null   object
#  12  Segment       9994 non-null   object
#  13  Product       9994 non-null   object
#  14  License       9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
#  17  Discount      9994 non-null   float64
#  18  Profit        9994 non-null   float64
# dtypes: float64(3), int64(4), object(12)
# memory usage: 1.4+ MB

# %%
# Tipos de datos
print("TIPOS DE DATOS")
print(df.dtypes)
# Out:
# TIPOS DE DATOS
# Row ID            int64
# Order ID         object
# Order Date       object
# Date Key          int64
# Contact Name     object
# Country          object
# City             object
# Region           object
# Subregion        object
# Customer         object
# Customer ID       int64
# Industry         object
# Segment          object
# Product          object
# License          object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Estadísticas descriptivas de variables numéricas
print("ESTADÍSTICAS DESCRIPTIVAS - VARIABLES NUMÉRICAS")
display(df.describe().T)

# Estadísticas adicionales
print("ESTADÍSTICAS ADICIONALES")
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in numeric_cols:
    print(f"\n{col}:")
    print(f"  Media: {df[col].mean():.2f}")
    print(f"  Mediana: {df[col].median():.2f}")
    print(f"  Moda: {df[col].mode().values[0] if len(df[col].mode()) > 0 else 'N/A'}")
    print(f"  Desviación estándar: {df[col].std():.2f}")
    print(f"  Varianza: {df[col].var():.2f}")
    print(f"  Asimetría (Skewness): {df[col].skew():.2f}")
    print(f"  Curtosis (Kurtosis): {df[col].kurtosis():.2f}")
# Out:
# ESTADÍSTICAS DESCRIPTIVAS - VARIABLES NUMÉRICAS
#               count          mean           std           min           25%  \
# Row ID       9994.0  4.997500e+03   2885.163629  1.000000e+00  2.499250e+03
# Date Key     9994.0  2.021803e+07  11238.975964  2.020010e+07  2.021052e+07
# Customer ID  9994.0  1.049772e+03     29.719388  1.001000e+03  1.024000e+03
# Sales        9994.0  2.298580e+02    623.245101  4.440000e-01  1.728000e+01
# Quantity     9994.0  3.789574e+00      2.225110  1.000000e+00  2.000000e+00
# Discount     9994.0  1.562027e-01      0.206452  0.000000e+00  0.000000e+00
# Profit       9994.0  2.865690e+01    234.260108 -6.599978e+03  1.728750e+00
#
#                       50%           75%           max
# Row ID       4.997500e+03  7.495750e+03  9.994000e+03
# Date Key     2.022063e+07  2.023052e+07  2.023123e+07
# Customer ID  1.049000e+03  1.076000e+03  1.101000e+03
# Sales        5.449000e+01  2.099400e+02  2.263848e+04
# Quantity     3.000000e+00  5.000000e+00  1.400000e+01
# Discount     2.000000e-01  2.000000e-01  8.000000e-01
# Profit       8.666500e+00  2.936400e+01  8.399976e+03
# ESTADÍSTICAS ADICIONALES
#
# Row ID:
#   Media: 4997.50
#   Mediana: 4997.50
#   Moda: 1
#   Desviación estándar: 2885.16
#   Varianza: 8324169.17
#   Asimetría (Skewness): 0.00
#   Curtosis (Kurtosis): -1.20
#
# Date Key:
#   Media: 20218026.47
#   Mediana: 20220627.00
#   Moda: 20220906
#   Desviación estándar: 11238.98
#   Varianza: 126314580.71
#   Asimetría (Skewness): -0.28
#   Curtosis (Kurtosis): -1.31
#
# Customer ID:
#   Media: 1049.77
#   Mediana: 1049.00
#   Moda: 1080
#   Desviación estándar: 29.72
#   Varianza: 883.24
#   Asimetría (Skewness): 0.03
#   Curtosis (Kurtosis): -1.25
#
# Sales:
#   Media: 229.86
#   Mediana: 54.49
#   Moda: 12.96
#   Desviación estándar: 623.25
#   Varianza: 388434.46
#   Asimetría (Skewness): 12.97
#   Curtosis (Kurtosis): 305.31
#
# Quantity:
#   Media: 3.79
#   Mediana: 3.00
#   Moda: 3
#   Desviación estándar: 2.23
#   Varianza: 4.95
#   Asimetría (Skewness): 1.28
#   Curtosis (Kurtosis): 1.99
#
# Discount:
#   Media: 0.16
#   Mediana: 0.20
#   Moda: 0.0
#   Desviación estándar: 0.21
#   Varianza: 0.04
#   Asimetría (Skewness): 1.68
#   Curtosis (Kurtosis): 2.41
#
# Profit:
#   Media: 28.66
#   Mediana: 8.67
#   Moda: 0.0
#   Desviación estándar: 234.26
#   Varianza: 54877.80
#   Asimetría (Skewness): 7.56
#   Curtosis (Kurtosis): 397.19

# %%
# Estadísticas de variables categóricas
print("ESTADÍSTICAS DESCRIPTIVAS - VARIABLES CATEGÓRICAS")

categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\n{col}:")
    print(f"  Valores únicos: {df[col].nunique()}")
    print(f"  Valor más frecuente: {df[col].mode().values[0] if len(df[col].mode()) > 0 else 'N/A'}")
    print(f"  Top 5 valores:")
    print(df[col].value_counts().head())
# Out:
# ESTADÍSTICAS DESCRIPTIVAS - VARIABLES CATEGÓRICAS
#
# Order ID:
#   Valores únicos: 5009
#   Valor más frecuente: EMEA-2023-100111
#   Top 5 valores:
# Order ID
# EMEA-2023-100111    14
# EMEA-2023-157987    12
# AMER-2022-165330    11
# EMEA-2022-108504    11
# EMEA-2021-126977    10
# Name: count, dtype: int64
#
# Order Date:
#   Valores únicos: 1237
#   Valor más frecuente: 9/6/2022
#   Top 5 valores:
# Order Date
# 9/6/2022      38
# 9/3/2023      36
# 11/11/2022    35
# 12/2/2023     34
# 12/3/2023     34
# Name: count, dtype: int64
#
# Contact Name:
#   Valores únicos: 793
#   Valor más frecuente: Leonard Kelly
#   Top 5 valores:
# Contact Name
# Leonard Kelly      37
# Amelia Campbell    34
# Gordon Parr        34
# Tracey Dickens     34
# Evan Ince          32
# Name: count, dtype: int64
#
# Country:
#   Valores únicos: 48
#   Valor más frecuente: United States
#   Top 5 valores:
# Country
# United States     2001
# United Kingdom    1141
# Japan              985
# France             587
# Canada             506
# Name: count, dtype: int64
#
# City:
#   Valores únicos: 262
#   Valor más frecuente: London
#   Top 5 valores:
# City
# London           922
# New York City    740
# Paris            537
# Los Angeles      510
# Toronto          431
# Name: count, dtype: int64
#
# Region:
#   Valores únicos: 3
#   Valor más frecuente: EMEA
#   Top 5 valores:
# Region
# EMEA    4219
# AMER    3665
# APJ     2110
# Name: count, dtype: int64
#
# Subregion:
#   Valores únicos: 12
#   Valor más frecuente: NAMER
#   Top 5 valores:
# Subregion
# NAMER      2507
# EU-WEST    1614
# UKIR       1267
# LATAM      1158
# JAPN        985
# Name: count, dtype: int64
#
# Customer:
#   Valores únicos: 99
#   Valor más frecuente: Allianz
#   Top 5 valores:
# Customer
# Allianz        192
# Tyson Foods    184
# Ford Motor     176
# Siemens        170
# Comcast        161
# Name: count, dtype: int64
#
# Industry:
#   Valores únicos: 10
#   Valor más frecuente: Finance
#   Top 5 valores:
# Industry
# Finance          2127
# Energy           1316
# Tech             1236
# Manufacturing    1222
# Healthcare       1049
# Name: count, dtype: int64
#
# Segment:
#   Valores únicos: 3
#   Valor más frecuente: SMB
#   Top 5 valores:
# Segment
# SMB           5191
# Strategic     3020
# Enterprise    1783
# Name: count, dtype: int64
#
# Product:
#   Valores únicos: 14
#   Valor más frecuente: ContactMatcher
#   Top 5 valores:
# Product
# ContactMatcher         1842
# Support                1560
# FinanceHub              981
# SaaS Connector Pack     957
# Site Analytics          889
# Name: count, dtype: int64
#
# License:
#   Valores únicos: 9994
#   Valor más frecuente: 005Q2UQUDZ
#   Top 5 valores:
# License
# 3NTBV9B3PS    1
# 16GRM07R1K    1
# QLIW57KZUV    1
# JI6BVL70HQ    1
# DE9GJKGD44    1
# Name: count, dtype: int64

# %%
# Análisis de duplicados
print("ANÁLISIS DE VALORES DUPLICADOS")
print(f"Número de filas duplicadas: {df.duplicated().sum()}")
print(f"Porcentaje de duplicados: {(df.duplicated().sum() / len(df)) * 100:.2f}%")

if df.duplicated().sum() > 0:
    print("\nFilas duplicadas:")
    display(df[df.duplicated(keep=False)].sort_values(by=df.columns.tolist()))
# Out:
# ANÁLISIS DE VALORES DUPLICADOS
# Número de filas duplicadas: 0
# Porcentaje de duplicados: 0.00%

# %%
# Análisis de nulos
print("ANÁLISIS DE VALORES NULOS")
print(f"Total de valores nulos: {df.isnull().sum().sum()}")
print(f"Porcentaje de nulos sobre el total: {(df.isnull().sum().sum() / df.size) * 100:.2f}%")

print("\nNulos por columna:")
nulos_por_col = df.isnull().sum()
porcentaje_por_col = (df.isnull().sum() / len(df)) * 100
resumen_nulos = pd.DataFrame({
    'Nulos': nulos_por_col,
    'Porcentaje': porcentaje_por_col.map('{:.2f}%'.format)
})
display(resumen_nulos[resumen_nulos['Nulos'] > 0])

if df.isnull().sum().sum() > 0:
    print("\nFilas con al menos un nulo:")
    display(df[df.isnull().any(axis=1)])
# Out:
# ANÁLISIS DE VALORES NULOS
# Total de valores nulos: 0
# Porcentaje de nulos sobre el total: 0.00%
#
# Nulos por columna:
# Empty DataFrame
# Columns: [Nulos, Porcentaje]
# Index: []

# %%
# Boxplots para detectar outliers
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

if len(numeric_cols) > 0:
    n_cols = 3
    n_rows = (len(numeric_cols) + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
    axes = axes.flatten() if len(numeric_cols) > 1 else [axes]

    for idx, col in enumerate(numeric_cols):
        axes[idx].boxplot(df[col].dropna(), vert=True)
        axes[idx].set_title(f'Boxplot de {col}', fontweight='bold')
        axes[idx].set_ylabel(col)
        axes[idx].grid(alpha=0.3)

    # Ocultar ejes vacíos
    for idx in range(len(numeric_cols), len(axes)):
        axes[idx].set_visible(False)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Reconstrucción de DataSet

# %%
df['Reglas']= df['Region']+','+df['Subregion']+','+df['Industry']+','+df['Segment']+','+df['Product']
df.head()
# Out:
#    Row ID          Order ID  Order Date  Date Key    Contact Name  \
# 0       1  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 1       2  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 2       3  AMER-2022-138688   6/13/2022  20220613  Deirdre Bailey
# 3       4  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
# 4       5  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License  \
# 0         1017   Energy        SMB         Marketing Suite  16GRM07R1K
# 1         1017   Energy        SMB              FinanceHub  QLIW57KZUV
# 2         1056   Energy  Strategic              FinanceHub  JI6BVL70HQ
# 3         1031   Energy        SMB          ContactMatcher  DE9GJKGD44
# 4         1031   Energy        SMB  Marketing Suite - Gold  OIF7NY23WD
#
#       Sales  Quantity  Discount    Profit  \
# 0  261.9600         2      0.00   41.9136
# 1  731.9400         3      0.00  219.5820
# 2   14.6200         2      0.00    6.8714
# 3  957.5775         5      0.45 -383.0310
# 4   22.3680         2      0.20    2.5164
#
#                                            Reglas
# 0            EMEA,UKIR,Energy,SMB,Marketing Suite
# 1                 EMEA,UKIR,Energy,SMB,FinanceHub
# 2          AMER,NAMER,Energy,Strategic,FinanceHub
# 3          EMEA,EU-WEST,Energy,SMB,ContactMatcher
# 4  EMEA,EU-WEST,Energy,SMB,Marketing Suite - Gold

# %%
df.to_csv(directorio_proyecto+'\\data\\processed\\Software.csv', index=False)
